# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from sklearn import linear_model
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# # Importation de données

# %%
df = pd.read_excel('../dataset_indice_prix_moyens.xlsx', header=0)

# %%
df.head()
# Out:
#    ANNEE     MOIS  PROD_AL_  BOIS _NON_ALCOL  \
# 0   2012  JANVIER                       4.83
# 1   2012  FEVRIER                       0.13
# 2   2012     MARS                       0.18
# 3   2012    AVRIL                       0.12
# 4   2012      MAI                       0.04
#
#    BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# 0                                        4.18
# 1                                        0.08
# 2                                        0.08
# 3                                        0.05
# 4                                        0.02
#
#    ARTICLES HABILLEMENT ET CHAUSSURES  \
# 0                                4.91
# 1                                0.11
# 2                                0.21
# 3                                0.04
# 4                                0.02
#
#    LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# 0                                               3.44
# 1                                               0.09
# 2                                               0.36
# 3                                               0.10
# 4                                               0.01
#
#    MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  SANTE  \
# 0                                               4.93          6.14
# 1                                               0.05          0.16
# 2                                               0.08          0.12
# 3                                               0.04          0.04
# 4                                               0.00          0.04
#
#    TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# 0        2.24            2.06               2.56          1.11
# 1        0.09            0.40               0.21          0.00
# 2        0.95            0.08               0.08          0.00
# 3        0.84            0.00               0.02         -0.01
# 4        0.01            0.00               0.01          0.00
#
#    RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES  INDICE GENERAL
# 0                   4.60                      2.97        3.664167
# 1                   0.02                      0.04        0.115000
# 2                   0.14                      0.09        0.197500
# 3                   0.02                      0.04        0.108333
# 4                   0.01                      0.03        0.015833

# %% [markdown]
# # Séléction des variables

# %%
variables = list(df.columns[:-1]) #ici nous recuperons tous les variables sauf la variable explicative

variables
# Out:
# ['ANNEE',
#  'MOIS',
#  'PROD_AL_  BOIS _NON_ALCOL',
#  'BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS',
#  'ARTICLES HABILLEMENT ET CHAUSSURES',
#  'LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE',
#  'MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER',
#  'SANTE',
#  'TRANSPORTS',
#  'COMMUNICATIONS',
#  'LOISIR ET CULTURE',
#  'ENSEIGNEMENT',
#  'RESTAURANTS ET HOTELS',
#  'AUTRES BIENS ET SERVICES']

# %% [markdown]
# # Correlation entre les variables

# %%
df[variables].corr(method='spearman')
# Out:
#                                                        ANNEE  \
# ANNEE                                               1.000000
# PROD_AL_  BOIS _NON_ALCOL                           0.628941
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS          0.362834
# ARTICLES HABILLEMENT ET CHAUSSURES                  0.502016
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...  0.474675
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...  0.600814
# SANTE                                               0.569287
# TRANSPORTS                                          0.500007
# COMMUNICATIONS                                      0.560201
# LOISIR ET CULTURE                                   0.551843
# ENSEIGNEMENT                                        0.322425
# RESTAURANTS ET HOTELS                               0.560822
# AUTRES BIENS ET SERVICES                            0.594354
#
#                                                     PROD_AL_  BOIS _NON_ALCOL  \
# ANNEE                                                                0.628941
# PROD_AL_  BOIS _NON_ALCOL                                            1.000000
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                           0.787327
# ARTICLES HABILLEMENT ET CHAUSSURES                                   0.886798
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                   0.839783
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                   0.887664
# SANTE                                                                0.876720
# TRANSPORTS                                                           0.817454
# COMMUNICATIONS                                                       0.765896
# LOISIR ET CULTURE                                                    0.823051
# ENSEIGNEMENT                                                         0.676435
# RESTAURANTS ET HOTELS                                                0.872304
# AUTRES BIENS ET SERVICES                                             0.868514
#
#                                                     BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# ANNEE                                                                                 0.362834
# PROD_AL_  BOIS _NON_ALCOL                                                             0.787327
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                                            1.000000
# ARTICLES HABILLEMENT ET CHAUSSURES                                                    0.786629
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                                    0.696862
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                                    0.763608
# SANTE                                                                                 0.745865
# TRANSPORTS                                                                            0.793009
# COMMUNICATIONS                                                                        0.728703
# LOISIR ET CULTURE                                                                     0.776447
# ENSEIGNEMENT                                                                          0.681470
# RESTAURANTS ET HOTELS                                                                 0.758058
# AUTRES BIENS ET SERVICES                                                              0.726718
#
#                                                     ARTICLES HABILLEMENT ET CHAUSSURES  \
# ANNEE                                                                         0.502016
# PROD_AL_  BOIS _NON_ALCOL                                                     0.886798
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                                    0.786629
# ARTICLES HABILLEMENT ET CHAUSSURES                                            1.000000
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                            0.781144
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                            0.825381
# SANTE                                                                         0.782417
# TRANSPORTS                                                                    0.738261
# COMMUNICATIONS                                                                0.654459
# LOISIR ET CULTURE                                                             0.747589
# ENSEIGNEMENT                                                                  0.636305
# RESTAURANTS ET HOTELS                                                         0.805954
# AUTRES BIENS ET SERVICES                                                      0.818576
#
#                                                     LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# ANNEE                                                                                        0.474675
# PROD_AL_  BOIS _NON_ALCOL                                                                    0.839783
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                                                   0.696862
# ARTICLES HABILLEMENT ET CHAUSSURES                                                           0.781144
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                                           1.000000
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                                           0.838256
# SANTE                                                                                        0.778110
# TRANSPORTS                                                                                   0.754560
# COMMUNICATIONS                                                                               0.701070
# LOISIR ET CULTURE                                                                            0.816433
# ENSEIGNEMENT                                                                                 0.736995
# RESTAURANTS ET HOTELS                                                                        0.806236
# AUTRES BIENS ET SERVICES                                                                     0.764980
#
#                                                     MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  \
# ANNEE                                                                                        0.600814
# PROD_AL_  BOIS _NON_ALCOL                                                                    0.887664
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                                                   0.763608
# ARTICLES HABILLEMENT ET CHAUSSURES                                                           0.825381
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                                           0.838256
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                                           1.000000
# SANTE                                                                                        0.816843
# TRANSPORTS                                                                                   0.856350
# COMMUNICATIONS                                                                               0.783057
# LOISIR ET CULTURE                                                                            0.857964
# ENSEIGNEMENT                                                                                 0.720855
# RESTAURANTS ET HOTELS                                                                        0.849203
# AUTRES BIENS ET SERVICES                                                                     0.818282
#
#                                                        SANTE  TRANSPORTS  \
# ANNEE                                               0.569287    0.500007
# PROD_AL_  BOIS _NON_ALCOL                           0.876720    0.817454
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS          0.745865    0.793009
# ARTICLES HABILLEMENT ET CHAUSSURES                  0.782417    0.738261
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...  0.778110    0.754560
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...  0.816843    0.856350
# SANTE                                               1.000000    0.783926
# TRANSPORTS                                          0.783926    1.000000
# COMMUNICATIONS                                      0.770634    0.731605
# LOISIR ET CULTURE                                   0.842983    0.799292
# ENSEIGNEMENT                                        0.690189    0.714209
# RESTAURANTS ET HOTELS                               0.838085    0.763141
# AUTRES BIENS ET SERVICES                            0.860178    0.748050
#
#                                                     COMMUNICATIONS  \
# ANNEE                                                     0.560201
# PROD_AL_  BOIS _NON_ALCOL                                 0.765896
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                0.728703
# ARTICLES HABILLEMENT ET CHAUSSURES                        0.654459
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...        0.701070
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...        0.783057
# SANTE                                                     0.770634
# TRANSPORTS                                                0.731605
# COMMUNICATIONS                                            1.000000
# LOISIR ET CULTURE                                         0.813371
# ENSEIGNEMENT                                              0.647848
# RESTAURANTS ET HOTELS                                     0.741269
# AUTRES BIENS ET SERVICES                                  0.706046
#
#                                                     LOISIR ET CULTURE  \
# ANNEE                                                        0.551843
# PROD_AL_  BOIS _NON_ALCOL                                    0.823051
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                   0.776447
# ARTICLES HABILLEMENT ET CHAUSSURES                           0.747589
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...           0.816433
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...           0.857964
# SANTE                                                        0.842983
# TRANSPORTS                                                   0.799292
# COMMUNICATIONS                                               0.813371
# LOISIR ET CULTURE                                            1.000000
# ENSEIGNEMENT                                                 0.806181
# RESTAURANTS ET HOTELS                                        0.818821
# AUTRES BIENS ET SERVICES                                     0.824297
#
#                                                     ENSEIGNEMENT  \
# ANNEE                                                   0.322425
# PROD_AL_  BOIS _NON_ALCOL                               0.676435
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS              0.681470
# ARTICLES HABILLEMENT ET CHAUSSURES                      0.636305
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...      0.736995
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...      0.720855
# SANTE                                                   0.690189
# TRANSPORTS                                              0.714209
# COMMUNICATIONS                                          0.647848
# LOISIR ET CULTURE                                       0.806181
# ENSEIGNEMENT                                            1.000000
# RESTAURANTS ET HOTELS                                   0.718355
# AUTRES BIENS ET SERVICES                                0.739851
#
#                                                     RESTAURANTS ET HOTELS  \
# ANNEE                                                            0.560822
# PROD_AL_  BOIS _NON_ALCOL                                        0.872304
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                       0.758058
# ARTICLES HABILLEMENT ET CHAUSSURES                               0.805954
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...               0.806236
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...               0.849203
# SANTE                                                            0.838085
# TRANSPORTS                                                       0.763141
# COMMUNICATIONS                                                   0.741269
# LOISIR ET CULTURE                                                0.818821
# ENSEIGNEMENT                                                     0.718355
# RESTAURANTS ET HOTELS                                            1.000000
# AUTRES BIENS ET SERVICES                                         0.865733
#
#                                                     AUTRES BIENS ET SERVICES
# ANNEE                                                               0.594354
# PROD_AL_  BOIS _NON_ALCOL                                           0.868514
# BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS                          0.726718
# ARTICLES HABILLEMENT ET CHAUSSURES                                  0.818576
# LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUS...                  0.764980
# MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT...                  0.818282
# SANTE                                                               0.860178
# TRANSPORTS                                                          0.748050
# COMMUNICATIONS                                                      0.706046
# LOISIR ET CULTURE                                                   0.824297
# ENSEIGNEMENT                                                        0.739851
# RESTAURANTS ET HOTELS                                               0.865733
# AUTRES BIENS ET SERVICES                                            1.000000

# %% [markdown]
# # Codification des variables qualitatives

# %%
convertion_dict = {'MOIS': {'JANVIER': 1, 'FEVRIER' : 2, 'MARS': 3, 'AVRIL' : 4, 'MAI' : 5, 'JUIN' : 6, 'JUILLET' : 7, 'AOUT' : 8, 'SEPTEMBRE' : 9, 'OCTOBRE' : 10, 'NOVEMBRE' : 11, 'DECEMBRE' : 12}}

df.replace(to_replace=convertion_dict, inplace=True)

df.head()
# Out:
#    ANNEE  MOIS  PROD_AL_  BOIS _NON_ALCOL  \
# 0   2012     1                       4.83
# 1   2012     2                       0.13
# 2   2012     3                       0.18
# 3   2012     4                       0.12
# 4   2012     5                       0.04
#
#    BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# 0                                        4.18
# 1                                        0.08
# 2                                        0.08
# 3                                        0.05
# 4                                        0.02
#
#    ARTICLES HABILLEMENT ET CHAUSSURES  \
# 0                                4.91
# 1                                0.11
# 2                                0.21
# 3                                0.04
# 4                                0.02
#
#    LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# 0                                               3.44
# 1                                               0.09
# 2                                               0.36
# 3                                               0.10
# 4                                               0.01
#
#    MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  SANTE  \
# 0                                               4.93          6.14
# 1                                               0.05          0.16
# 2                                               0.08          0.12
# 3                                               0.04          0.04
# 4                                               0.00          0.04
#
#    TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# 0        2.24            2.06               2.56          1.11
# 1        0.09            0.40               0.21          0.00
# 2        0.95            0.08               0.08          0.00
# 3        0.84            0.00               0.02         -0.01
# 4        0.01            0.00               0.01          0.00
#
#    RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES  INDICE GENERAL
# 0                   4.60                      2.97        3.664167
# 1                   0.02                      0.04        0.115000
# 2                   0.14                      0.09        0.197500
# 3                   0.02                      0.04        0.108333
# 4                   0.01                      0.03        0.015833

# %%
df[variables].corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col1 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col2 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col5 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col7 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col8 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col9 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col10 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col11 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col12 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow0_col13 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col3 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col4 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col5 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col6 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col7 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col8 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col9 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col10 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col11 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col12 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow2_col13 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col0 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col2 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col4 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col5 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col6 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col7 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col8 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col9 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col10 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col11 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col12 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow3_col13 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow4_col0 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow4_col1 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow4_col2 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_3198bf62_9bcf_11ed_8e4e_c0b883758aaerow4_col3 {
#             background-color:  #ec7f63;
#             colo

# %%
variables_new = list(df.columns[2:-1]) #ici nous recuperons toutes les variables qui sont correlées

variables_new
# Out:
# ['PROD_AL_  BOIS _NON_ALCOL',
#  'BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS',
#  'ARTICLES HABILLEMENT ET CHAUSSURES',
#  'LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE',
#  'MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER',
#  'SANTE',
#  'TRANSPORTS',
#  'COMMUNICATIONS',
#  'LOISIR ET CULTURE',
#  'ENSEIGNEMENT',
#  'RESTAURANTS ET HOTELS',
#  'AUTRES BIENS ET SERVICES']

# %% [markdown]
# # chargement Matrice X

# %%
X = df[variables_new]

X.head()
# Out:
#    PROD_AL_  BOIS _NON_ALCOL  BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# 0                       4.83                                        4.18
# 1                       0.13                                        0.08
# 2                       0.18                                        0.08
# 3                       0.12                                        0.05
# 4                       0.04                                        0.02
#
#    ARTICLES HABILLEMENT ET CHAUSSURES  \
# 0                                4.91
# 1                                0.11
# 2                                0.21
# 3                                0.04
# 4                                0.02
#
#    LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# 0                                               3.44
# 1                                               0.09
# 2                                               0.36
# 3                                               0.10
# 4                                               0.01
#
#    MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  SANTE  \
# 0                                               4.93          6.14
# 1                                               0.05          0.16
# 2                                               0.08          0.12
# 3                                               0.04          0.04
# 4                                               0.00          0.04
#
#    TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# 0        2.24            2.06               2.56          1.11
# 1        0.09            0.40               0.21          0.00
# 2        0.95            0.08               0.08          0.00
# 3        0.84            0.00               0.02         -0.01
# 4        0.01            0.00               0.01          0.00
#
#    RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES
# 0                   4.60                      2.97
# 1                   0.02                      0.04
# 2                   0.14                      0.09
# 3                   0.02                      0.04
# 4                   0.01                      0.03

# %% [markdown]
# # Analyse descriptive

# %%
X.describe()
# Out:
#        PROD_AL_  BOIS _NON_ALCOL  BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# count                 122.000000                                  122.000000
# mean                    1.255984                                    0.973934
# std                     2.563012                                    2.176955
# min                     0.030000                                    0.010000
# 25%                     0.150000                                    0.060000
# 50%                     0.295000                                    0.095000
# 75%                     0.827500                                    0.480000
# max                    15.750000                                   11.640000
#
#        ARTICLES HABILLEMENT ET CHAUSSURES  \
# count                          122.000000
# mean                             1.374508
# std                              2.770255
# min                              0.010000
# 25%                              0.100000
# 50%                              0.205000
# 75%                              1.087500
# max                             17.370000
#
#        LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# count                                         122.000000
# mean                                            1.070246
# std                                             2.230286
# min                                             0.010000
# 25%                                             0.110000
# 50%                                             0.260000
# 75%                                             0.725000
# max                                            14.400000
#
#        MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER       SANTE  \
# count                                         122.000000         122.000000
# mean                                            0.967951           1.666475
# std                                             1.916653           4.051765
# min                                             0.000000           0.020000
# 25%                                             0.070000           0.080000
# 50%                                             0.225000           0.305000
# 75%                                             0.715000           1.055000
# max                                             9.440000          26.160000
#
#        TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# count  122.000000      122.000000         122.000000    122.000000
# mean     0.803197        1.047213           0.931393      0.784508
# std      1.497747        2.455842           1.931994      1.749408
# min     -0.100000        0.000000           0.000000     -0.010000
# 25%      0.070000        0.052500           0.060000      0.020000
# 50%      0.235000        0.140000           0.120000      0.090000
# 75%      0.797500        1.067500           0.640000      0.460000
# max      8.740000       20.140000          10.390000      8.850000
#
#        RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES
# count             122.000000                122.000000
# mean                1.187213                  1.001557
# std                 2.498233                  1.992273
# min                 0.000000                  0.010000
# 25%                 0.100000                  0.090000
# 50%                 0.185000                  0.235000
# 75%                 0.750000                  0.735000
# max                15.410000                 10.900000

# %% [markdown]
# # chargement de vecteur classe y

# %%
y = df[df.columns[-1]]

y.head()
# Out:
# 0    3.664167
# 1    0.115000
# 2    0.197500
# 3    0.108333
# 4    0.015833
# Name: INDICE GENERAL, dtype: float64

# %%
plt.hist(y)
# Out:
# (array([99.,  5.,  6.,  5.,  1.,  1.,  0.,  1.,  2.,  2.]),
#  array([ 0.01416667,  1.14225   ,  2.27033333,  3.39841667,  4.5265    ,
#          5.65458333,  6.78266667,  7.91075   ,  9.03883333, 10.16691667,
#         11.295     ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Normalisation et gestion de valeurs manquantes

# %%
imputer_model = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer_model.fit(X)

X = imputer_model.transform(X)

X
# Out:
# array([[4.83, 4.18, 4.91, ..., 1.11, 4.6 , 2.97],
#        [0.13, 0.08, 0.11, ..., 0.  , 0.02, 0.04],
#        [0.18, 0.08, 0.21, ..., 0.  , 0.14, 0.09],
#        ...,
#        [0.82, 0.14, 0.22, ..., 0.24, 0.67, 0.47],
#        [0.67, 0.12, 0.22, ..., 0.16, 0.56, 0.44],
#        [0.45, 0.12, 0.14, ..., 0.09, 0.29, 0.29]])

# %%
for x in X:
    plt.hist(x)

# %% [markdown]
# ### Segmentation de l'ensemble de données en sous-ensembles d'entraînement (training set) et de test (test set)
# Nous optons de faire une segmentation de l'ensemble de données en ensembles d'apprentissage et de test comprenant chacun repectivement <b>70%</b> et <b>30%</b> des données.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state = 0)

# %% [markdown]
# ### Création du modèle
#
# a. Regression Linéaire

# %%
modele_regression = linear_model.LinearRegression()

# %% [markdown]
# #### Apprentissage

# %%
modele_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
precision_reg = modele_regression.score(X_test, y_test)

test_error_regression = np.mean((modele_regression.predict(X_test) - y_test) ** 2)

train_error_regression = np.mean((modele_regression.predict(X_train) - y_train) ** 2)

print('Coefficients: \n', modele_regression.coef_) # coefficients

print ('intercept', modele_regression.intercept_) # la constante

print("Residual sum of squares test: %.2f" % test_error_regression) #Erreur quadratique moyenne

print("Residual sum of squares train: %.2f" % train_error_regression) #Erreur quadratique moyenne

print("La précision du modèle de regression est de", np.round(precision_reg * 100, 2), "%")
# Out:
# Coefficients:
#  [0.08333333 0.08333333 0.08333333 0.08333333 0.08333333 0.08333333
#  0.08333333 0.08333333 0.08333333 0.08333333 0.08333333 0.08333333]
# intercept 3.3306690738754696e-16
# Residual sum of squares test: 0.00
# Residual sum of squares train: 0.00
# La précision du modèle de regression est de 100.0 %

# %% [markdown]
# #### fonction de prédiction de modèle de regression multiple
#
# indice = ∑〖βi*Xi〗+ b

# %%
i = 0
model = ''
for x in modele_regression.coef_:
        model = model + str(x)+' * X'+str(i + 1) + ' + '
        i = i + 1
    
model = 'y_predited(INDICE) = '+ model + str(modele_regression.intercept_)

model
# Out:
# 'y_predited(INDICE) = 0.083333333333334 * X1 + 0.08333333333333244 * X2 + 0.0833333333333337 * X3 + 0.08333333333333319 * X4 + 0.0833333333333336 * X5 + 0.08333333333333326 * X6 + 0.08333333333333319 * X7 + 0.08333333333333331 * X8 + 0.08333333333333312 * X9 + 0.08333333333333331 * X10 + 0.08333333333333309 * X11 + 0.08333333333333323 * X12 + 3.3306690738754696e-16'

# %% [markdown]
# b. Forêt aléatoire modele de regression

# %%
modele_forest = RandomForestRegressor()

# %% [markdown]
# #### Apprentissage

# %%
modele_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_forest_predited = modele_forest.predict(X_test)

score = r2_score(y_test, y_forest_predited)

test_error_forest = np.mean((y_forest_predited - y_test) ** 2)

train_error_forest = np.mean((modele_forest.predict(X_train) - y_train) ** 2)

print ('nombre d\'arbre est', len(modele_forest.estimators_)) # le nombre d'arbre

print("La précision du modèle de forêt aléatoire est de", np.round(score * 100, 2), "%")

print("Residual sum of squares test: %.2f" % test_error_forest) #Erreur quadratique moyenne

print("Residual sum of squares train: %.2f" % train_error_forest) #Erreur quadratique moyenne
# Out:
# nombre d'arbre est 100
# La précision du modèle de forêt aléatoire est de 95.5 %
# Residual sum of squares test: 0.38
# Residual sum of squares train: 0.02

# %% [markdown]
# c. Arbre de decison modèle de regression

# %%
modele_arb = tree.DecisionTreeRegressor()

# %% [markdown]
# #### Apprentissage

# %%
modele_arb.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
precision_arb = modele_arb.score(X_test, y_test)

test_error_arb = np.mean((modele_arb.predict(X_test) - y_test) ** 2)

train_error_arb = np.mean((modele_arb.predict(X_train) - y_train) ** 2)

print("Residual sum of squares test: %.2f" % test_error_arb) #Erreur quadratique moyenne

print("Residual sum of squares train: %.2f" % train_error_arb) #Erreur quadratique moyenne

print("La précision du modèle est de", np.round(precision_arb * 100, 2), "%")
# Out:
# Residual sum of squares test: 0.18
# Residual sum of squares train: 0.00
# La précision du modèle est de 97.92 %

# %% [markdown]
# ## Comparaison des modèles
#
# Regression multiple, Forêt aléatoire de regression et Arbre de decision de regression

# %%
print("La précision du modèle :\n Regression multiple est de ",np.round(precision_reg * 100, 2), "%", 
      "\n Forêt aléatoire Regression est de ", np.round(score * 100, 2), "%",
     "\n Arbre de decision Regression est de", np.round(precision_arb * 100, 2), "%"
     )
# Out:
# La précision du modèle :
#  Regression multiple est de  100.0 %
#  Forêt aléatoire Regression est de  95.5 %
#  Arbre de decision Regression est de 97.92 %

# %%
train_error = [train_error_regression, train_error_forest, train_error_arb]

test_error = [test_error_regression, test_error_forest, test_error_arb]

precision_model = [np.round(precision_reg * 100, 2), np.round(score * 100, 2), np.round(precision_arb * 100, 2)]

data = {'Train Error' : train_error, 'Test Error' : test_error, 'Précision modele %' : precision_model}

models = ['Regression Multiple', 'Forêt alétaoire Regression', 'Arbre de decison regression']

df_compare = pd.DataFrame(data, index = models)

df_compare
# Out:
#                               Train Error    Test Error  Précision modele %
# Regression Multiple          5.263094e-31  1.473805e-30              100.00
# Forêt alétaoire Regression   2.278776e-02  3.819362e-01               95.50
# Arbre de decison regression  4.531600e-36  1.762785e-01               97.92

# %%
df_compare.plot(kind='bar')

# %% [markdown]
# ### Prédiction de nouvelle données
#
# chargement de nouvelles données

# %%
INPUT = [[2012, 'JANVIER', 4.83, 4.18, 4.91, 3.44, 4.93, 6.14, 2.24, 2.06, 2.56, 1.11, 4.60, 2.97],
        [2022, 'FEVRIER', 0.45, 0.12, 0.14, 0.58, 0.25, 0.21, 0.33, 1.32, 0.25, 0.09, 0.29, 0.29]]

INPUT

df_new = pd.DataFrame(data = INPUT, columns=variables)

#Normalisation des données
new_X = df_new[variables_new]

new_X = imputer_model.transform(new_X)

new_X
# Out:
# array([[4.83, 4.18, 4.91, 3.44, 4.93, 6.14, 2.24, 2.06, 2.56, 1.11, 4.6 ,
#         2.97],
#        [0.45, 0.12, 0.14, 0.58, 0.25, 0.21, 0.33, 1.32, 0.25, 0.09, 0.29,
#         0.29]])

# %% [markdown]
# Prédiction avec le modèle de Regression

# %%
y_predited_reg = modele_regression.predict(new_X)
y_predited_reg
# Out:
# array([3.66416667, 0.36      ])

# %% [markdown]
# Prédiction avec le modèle de forêt aléatoire

# %%
y_predited_forest = modele_forest.predict(new_X)
y_predited_forest
# Out:
# array([3.73581667, 0.37924167])

# %% [markdown]
# Prédiction avec le modèle d'abre de decison rgression

# %%
y_predited_arb = modele_arb.predict(new_X)
y_predited_arb
# Out:
# array([3.66416667, 0.40083333])

# %%
dict ={'INDICE GENERAL REGRESSION' : y_predited_reg, 'INDICE GENERAL FOREST' : y_predited_forest, 'INDICE GENERAL ARBRE' : y_predited_arb}

df_clf = pd.DataFrame(dict, columns =['INDICE GENERAL REGRESSION', 'INDICE GENERAL FOREST', 'INDICE GENERAL ARBRE'])

out = pd.merge(df_new, df_clf , right_index=True, left_index=True)

out
# Out:
#    ANNEE     MOIS  PROD_AL_  BOIS _NON_ALCOL  \
# 0   2012  JANVIER                       4.83
# 1   2022  FEVRIER                       0.45
#
#    BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# 0                                        4.18
# 1                                        0.12
#
#    ARTICLES HABILLEMENT ET CHAUSSURES  \
# 0                                4.91
# 1                                0.14
#
#    LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# 0                                               3.44
# 1                                               0.58
#
#    MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  SANTE  \
# 0                                               4.93          6.14
# 1                                               0.25          0.21
#
#    TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# 0        2.24            2.06               2.56          1.11
# 1        0.33            1.32               0.25          0.09
#
#    RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES  INDICE GENERAL REGRESSION  \
# 0                   4.60                      2.97                   3.664167
# 1                   0.29                      0.29                   0.360000
#
#    INDICE GENERAL FOREST  INDICE GENERAL ARBRE
# 0               3.735817              3.664167
# 1               0.379242              0.400833

# %% [markdown]
# # Variation des indices
#
# (Prix du panier au 1er mois Année+1)/(Prix du panier au 1er mois Année-1)  x 100

# %%
convertion_dict = {'MOIS': {1 : 'JANVIER', 2 : 'FEVRIER', 3: 'MARS', 4 : 'AVRIL', 5 : 'MAI', 6 : 'JUIN', 7 : 'JUILLET', 8 : 'AOUT', 9 : 'SEPTEMBRE', 10 :'OCTOBRE', 11 : 'NOVEMBRE', 12 : 'DECEMBRE'}}

def get_indice_in_df(df, year, month) :
    indice = 0.0 
    df.replace(to_replace=convertion_dict, inplace=True)
    df = df.reset_index()  # make sure indexes pair with number of rows

    for index, row in df.iterrows():
        if row['MOIS'] == (month) and row['ANNEE'] == year :
            indice = row['INDICE GENERAL']
            break
            
    return indice
    

min_v = df[['ANNEE']].min().astype(int)
max_v = df[['ANNEE']].max().astype(int)

for m, y in zip(['JANVIER', 'FEVRIER', 'MARS', 'AVRIL', 'MAI', 'JUIN', 'JUILLET', 'AOUT', 'SEPTEMBRE', 'OCTOBRE', 'NOVEMBRE', 'DECEMBRE'], range(2012, 2022)):
        num = get_indice_in_df(df_copy, y + 1, m) 
        den = get_indice_in_df(df_copy, y, m)
        
        num = 0 if num is None else num
        den = 0 if den is None else den
        
        variation = 0 if den is None or num is None else (num/den) * 100        
        
        print(num, "(", y + 1, ") / ", den, "(", y, ") * 100 = ", variation)
        
df_copy
# Out:
# 0.08833333333333333 ( 2013 )/ 3.664166666666667 ( 2012 ) * 100 =  2.4107345917671137
# 0.11166666666666665 ( 2014 )/ 0.12000000000000001 ( 2013 ) * 100 =  93.05555555555554
# 0.07583333333333335 ( 2015 )/ 0.015833333333333335 ( 2014 ) * 100 =  478.94736842105266
# 0.27666666666666667 ( 2016 )/ 0.09333333333333332 ( 2015 ) * 100 =  296.4285714285715
# 4.9816666666666665 ( 2017 )/ 0.1266666666666667 ( 2016 ) * 100 =  3932.894736842104
# 0.7683333333333334 ( 2018 )/ 9.535833333333333 ( 2017 ) * 100 =  8.057327623874858
# 0.19833333333333333 ( 2019 )/ 0.23499999999999996 ( 2018 ) * 100 =  84.39716312056738
# 0.9166666666666666 ( 2020 )/ 0.18666666666666668 ( 2019 ) * 100 =  491.07142857142856
# 0.3925 ( 2021 )/ 0.4008333333333333 ( 2020 ) * 100 =  97.92099792099793
# 0.0 ( 2022 )/ 0.43916666666666665 ( 2021 ) * 100 =  0.0
#      ANNEE      MOIS  PROD_AL_  BOIS _NON_ALCOL  \
# 0     2012   JANVIER                       4.83
# 1     2012   FEVRIER                       0.13
# 2     2012      MARS                       0.18
# 3     2012     AVRIL                       0.12
# 4     2012       MAI                       0.04
# ..     ...       ...                        ...
# 117   2021   OCTOBRE                       0.43
# 118   2021  NOVEMBRE                       0.54
# 119   2021  DECEMBRE                       0.82
# 120   2022   JANVIER                       0.67
# 121   2022   FEVRIER                       0.45
#
#      BOISSONS ALCOLISEES, TABACS ET STUPIFIANTS  \
# 0                                          4.18
# 1                                          0.08
# 2                                          0.08
# 3                                          0.05
# 4                                          0.02
# ..                                          ...
# 117                                        0.03
# 118                                        0.09
# 119                                        0.14
# 120                                        0.12
# 121                                        0.12
#
#      ARTICLES HABILLEMENT ET CHAUSSURES  \
# 0                                  4.91
# 1                                  0.11
# 2                                  0.21
# 3                                  0.04
# 4                                  0.02
# ..                                  ...
# 117                                0.09
# 118                                0.09
# 119                                0.22
# 120                                0.22
# 121                                0.14
#
#      LOGEMENT EAU, GAZ, ELECTRICITE ET AUTRES COMBUSTIBLE  \
# 0                                                 3.44
# 1                                                 0.09
# 2                                                 0.36
# 3                                                 0.10
# 4                                                 0.01
# ..                                                 ...
# 117                                               0.44
# 118                                               0.85
# 119                                               1.17
# 120                                               0.90
# 121                                               0.58
#
#      MEUBLES, ARTICLE DE MENAGE ET ENTRETIEN COURANT DU FOYER  SANTE  \
# 0                                                 4.93          6.14
# 1                                                 0.05          0.16
# 2                                                 0.08          0.12
# 3                                                 0.04          0.04
# 4                                                 0.00          0.04
# ..                                                 ...           ...
# 117                                               0.36          0.41
# 118                                               0.31          0.32
# 119                                               0.41          0.34
# 120                                               0.25          0.30
# 121                                               0.25          0.21
#
#      TRANSPORTS  COMMUNICATIONS  LOISIR ET CULTURE  ENSEIGNEMENT  \
# 0          2.24            2.06               2.56          1.11
# 1          0.09            0.40               0.21          0.00
# 2          0.95            0.08               0.08          0.00
# 3          0.84            0.00               0.02         -0.01
# 4          0.01            0.00               0.01          0.00
# ..          ...             ...                ...           ...
# 117        0.27            1.09               0.82          0.47
# 118        0.11            2.04               0.51          0.32
# 119        0.29            3.25               0.60          0.24
# 120        0.49            2.62               0.40          0.16
# 121        0.33            1.32               0.25          0.09
#
#      RESTAURANTS ET HOTELS  AUTRES BIENS ET SERVICES  INDICE GENERAL
# 0                     4.60                      2.97        3.664167
# 1                     0.02                      0.04        0.115000
# 2                     0.14                      0.09        0.197500
# 3                     0.02                      0.04        0.108333
# 4                     0.01                      0.03        0.015833
# ..                     ...                       ...             ...
# 117                   0.76                      0.10        0.439167
# 118                   0.36                      0.35        0.490833
# 119                   0.67                      0.47        0.718333
# 120                   0.56                      0.44        0.594167
# 121                   0.29                      0.29        0.360000
#
# [122 rows x 15 columns]
